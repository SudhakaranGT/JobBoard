# %%
import fitz
import os
import spacy

# %%
def extract_text_from_pdf(pdf_path):
    document = fitz.open(pdf_path)
    text = ""
    for page_num in range(document.page_count):
        page = document.load_page(page_num)
        text += page.get_text()
    return text

# pdf_path = "Vishwaa D A - Batch 2025 - B.Tech. - Information Technology - mjXj5ZC (1).pdf"
pdf_path = "September.pdf"
resume_text = extract_text_from_pdf(pdf_path)
print(resume_text)
# Out:
# SUDHAKARAN
# THIRUNAVUKKARASU
# B.Tech. - Information Technology
# Ph: +91-9952655991
# Email: sudhakaran2110507@ssn.edu.in
# Vandavasi, Tamil Nadu, India - 604501
# LinkedIn: https://www.linkedin.com/in/sudhakaran-gt
# Python  Java  C++  C  Javascript  Web Development  ReactJS  Node.js  Express.js  Spring Boot  SQL
# PostgreSQL  MongoDB  R  Excel  Power BI  Tableau
# BRIEF SUMMARY
# I am a final year IT student who focuses on Full stack development and data analysis, with expertise in Python, C++, R, SQL, and
# Java, excelling in handling intricate datasets and extracting valuable insights. Proficient in data visualization with Tableau and Excel,
# and skilled in web development with HTML, CSS, and JavaScript, I am excited to take on real-world challenges. I utilise React.js for
# interactive frontend development, Node.js/Express for flexible backend APIs, and Spring Boot for Java-based backend solutions to
# incorporate advanced ML and AI techniques in deploying predictive models and optimizing data processing.
# KEY EXPERTISE
# EDUCATION
# 2021  -  2025
# Sri Sivasubramaniya Nadar College of Engineering (SSN), Chennai
# B.Tech. - Information Technology |  CGPA: 7.72 / 10
# 2021
# Govt.Hr.Sec.School,Kunnagampoondi, Vandavasi
# 12th |  TNBSE |  Percentage: 94 / 100
# 2021
# Govt.Hr.Sec.School,Kunnnagampoondi, Vandavasi
# 10th |  TNBSE |  Percentage: 91 / 100
# AWARDS AND SCHOLARSHIPS
# National Means-cum-merit Scholarship Scheme(NMMS) Related to School
# Tamil Nadu Rural Students Talent Search Examination (TRUST) Related to School
# Scholarship for Potential Under-graduate Rural Students (SPURS) Related to SSN
# INTERNSHIPS
# 20 Jun, 2024  - 20 Aug, 2024
# Rocketlane  | IT Product & Services
# Software Engineer
# Key Skills: Java  Spring Boot  ReactJS  CSS
# During my internship at Rocketlane, a SaaS-based product company, I worked extensively with React ,Java Spring Boot and
# PostgreSQL. My primary focus was on resolving bugs, addressing design issues, and refactoring code to enhance efficiency and
# maintainability. This role allowed me to apply my technical knowledge in a practical setting, improving my problem-solving skills and
# understanding of software development.
# PROJECTS
# 20 Jun, 2024  -  28 Jun, 2024
# LeaveManager
# Key Skills: ReactJS  CSS  Java  Spring Boot  PostgreSQL
# Project Link:  https://github.com/SudhakaranGT/LeaveManager
# Frontend Developer | During my first week at Rocketlane, I developed a leave manager application, I focused on the frontend. I created
# a user-friendly interface and implemented form functionalities, applying my React and front-end development skills
# 01 Feb, 2024  -  31 May, 2024
# Job Board
# Key Skills: React.js  Node.js  Express.js  Machine Learning  Python  ML
# Project Link:  https://github.com/SudhakaranGT/JobBoard
# Lead Developer | a comprehensive job portal that utilises machine learning techniques for resume classification, resume ranking, and
# fraud detection in job listings.
# 01 Mar, 2024  -  31 Mar, 2024
# Real Estate Web
# Key Skills: React.js  CSS
# Project Link:  https://github.com/SudhakaranGT/RealEstateWeb
# A frontend web app for a real estate using React.
# 01 Nov, 2023  -  04 Dec, 2023
# T20 2022 - Cricket Data Analysis
# Key Skills: Power BI  Web Scraping  Python
# Data collected through web scrapping method and comprehensive dashboard for analysis using power BI
# 01 Sep, 2023  -  30 Nov, 2023
# Sign Language Translation
# Mentor: Mrs.Sornavalli |  Team Size: 3
# Key Skills: Python  Opencv  Mediapipe  Tensorflow  MongoDB  Deep Learning
# Project Link:  https://github.com/SudhakaranGT/Sign-Language-Translation
# Scrum Master|
# Developing a software for converting a sign into a text language and Speech into a sign images using deep learning models.
# 01 Mar, 2023  -  09 Aug, 2023
# Plagiarism Checker
# Mentor: Dr.Mohanavalli |  Team Size: 6
# Key Skills: Python  Data Base  Flask  HTML  CSS  Javascript
# Project Link:  https://github.com/SudhakaranGT/Plagarism-Checker
# Lead Developer| A Web Application for finding similarity index between two documents and Web design, implementation in HTML , CSS
# , establishing connection using Flask ,implementation of Advanced Data Structure.
# 01 Feb, 2022  -  31 May, 2022
# Package Delivery System
# Mentor: Dr. Karthika |  Team Size: 5
# Key Skills: Python  Data Structures  Tkinter
# Project Link:  https://github.com/SudhakaranGT/Package-Delivery-System
# Lead Developer | a Python project implementing a package delivery system using data structures and tkinter for the graphical user
# interface.
# ACHIEVEMENTS
# School Topper in both SSLC and HSC
# School Pupil Leader
# 5 Star for Python in Hacker Rank
# ASSESSMENTS / CERTIFICATIONS
# Google| Data Analytics Professional Certificate
# Aggregate: 91.37 / 100
# Key Skills: Data Analytics  Data Analysis  SQL  Spreadsheets  Excel  R  Tableau
# Studying extensive job-ready Google Career Certificate Training. Demonstrate hands on experience with data cleaning, data
# visualization, project management, interpreting and communicating data analytics findings.
# Certification Link:https://www.coursera.org/account/accomplishments/certificate/47CWN4RYEKHS
# Meta| Introduction to Front-End Development
# Aggregate: 96.68 / 100
# Key Skills: HTML  CSS  Bootstrap  React  Git
# A key Course that helped me to understanding and creating websites
# Certification link:https://www.coursera.org/account/accomplishments/certificate/B4R5CP9XTFJS
# NPTEL | Ethical Hacking
# Aggregate: 70 / 100
# Key Skills: Networking
# Gender: Male
# Marital Status: Single
# Current Address: 359,Pillaiyar Kovil Street, C.M.pudur ,Desur
# 604501, Vandavasi Taluk,Thiruvannamalai District, Vandavasi,
# Tamil Nadu, India - 604501
# Date of Birth: 23 Mar, 2004
# Known Languages: English,Tamil
# Phone Numbers: +91-9952655991, +91-9952655991
# Emails: sudhakaran2110507@ssn.edu.in , sudhakarangt@gmail.com
# PERSONAL INTERESTS / HOBBIES
# Chess
# WEB LINKS
# Other - https://codeforces.com/profile/GT_Sudhakaran
# Other - https://www.hackerrank.com/sudhakarangt
# Github - https://github.com/SudhakaranGT
# PERSONAL DETAILS

# %%
nlp = spacy.load("en_core_web_sm")

predefined_skills = ["Python","Java","C","C++","ReactJS","javascript"]
predefined_skills_lower = [skill.lower() for skill in predefined_skills]

def extract_skills(text, predefined_skills):
    doc = nlp(text)
    skills = []
    for token in doc:
        if token.text.lower() in predefined_skills:
            skills.append(token.text)
    return skills

skills_extracted = list(set(extract_skills(resume_text, predefined_skills_lower)))
print("Extracted skills: ",skills_extracted)
# Out:
# Extracted skills:  ['Python', 'C', 'ReactJS', 'Java', 'C++', 'JavaScript', 'Javascript']

# %%
def match_and_rank_resumes(resume_texts, required_skills):
    required_skills_lower = [skill.lower() for skill in required_skills]
    resume_rankings = []
    for resume_text in resume_texts:
        resume_text_lower = resume_text.lower()
        extracted_skills = extract_skills(resume_text_lower, predefined_skills_lower)
        matching_skills = set([skill.lower() for skill in extracted_skills]) & set(required_skills_lower)
        score = len(matching_skills)
        resume_rankings.append((resume_text, score))
    
    ranked_resumes = sorted(resume_rankings, key=lambda x: x[1], reverse=True)
    return ranked_resumes



def process_resumes(pdf_folder, required_skills):
    resume_texts = []

    for pdf_file in os.listdir(pdf_folder):
        if pdf_file.endswith(".pdf"):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            resume_text = extract_text_from_pdf(pdf_path)
            resume_texts.append(resume_text)
    
    #print(resume_texts)
    ranked_resumes = match_and_rank_resumes(resume_texts, required_skills)
    
    return ranked_resumes

pdf_folder = "resumes"
required_skills =  ["Python","Java","C","C++","ReactJs","javascript"]
ranked_resumes = process_resumes(pdf_folder, required_skills)

for idx, (resume, score) in enumerate(ranked_resumes):
    print(f"Resume {idx+1}: Score {score}")
# Out:
# Resume 1: Score 6
# Resume 2: Score 3
# Resume 3: Score 2
# Resume 4: Score 2
# Resume 5: Score 1

# %%
def match_and_rank_resumes2(resume_texts_with_paths, required_skills):
    required_skills_lower = [skill.lower() for skill in required_skills]
    resume_rankings = []
    for resume_text, path in resume_texts_with_paths:
        resume_text_lower = resume_text.lower()
        extracted_skills = extract_skills(resume_text_lower, required_skills_lower)
        matching_skills = set(skill.lower() for skill in extracted_skills) & set(required_skills_lower)
        score = len(matching_skills)
        resume_rankings.append((path, score))
    
    ranked_resumes = sorted(resume_rankings, key=lambda x: x[1], reverse=True)
    return ranked_resumes

def process_resumes2(pdf_folder, required_skills):
    resume_texts_with_paths = []

    for pdf_file in os.listdir(pdf_folder):
        if pdf_file.endswith(".pdf"):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            resume_text = extract_text_from_pdf(pdf_path)
            resume_texts_with_paths.append((resume_text, pdf_path))
    

    ranked_resumes = match_and_rank_resumes2(resume_texts_with_paths, required_skills)
    
    return ranked_resumes

pdf_folder = "resumes"
required_skills =  ["Python","Sql","Flask","API","OOPs"]
ranked_resumes = process_resumes2(pdf_folder, required_skills)

for idx, (path, score) in enumerate(ranked_resumes):
    print(f"Resume {idx+1}: Path {path}, Score {score}")
# Out:
# Resume 1: Path resumes\Vijay Veerasekaran - Batch 2025 - B.Tech. - Information Technology - iF5nlmC.pdf, Score 5
# Resume 2: Path resumes\Sujay R - Batch 2025 - B.Tech. - Information Technology - ydPZlmC (1).pdf, Score 4
# Resume 3: Path resumes\Vasundhara Boominathan - Batch 2025 - B.Tech. - Information Technology - 30S8lmC.pdf, Score 4
# Resume 4: Path resumes\Vishwaa D A - Batch 2025 - B.Tech. - Information Technology - mjXj5ZC (1).pdf, Score 4
# Resume 5: Path resumes\September.pdf, Score 3
